# %% [markdown]
# #References:
#
# - http://nbviewer.ipython.org/github/c3h3/NCCU-PyData-Courses-2013Spring/blob/master/Lecture1/crawler/Lecture2_WebCrawler.ipynb
#
# - [CSS Selector] http://www.w3schools.com/cssref/css_selectors.asp
# - [JQuery CSS] http://api.jquery.com/css/

# %% [markdown]
# ```
#     $("dl.col3f").map(function(){return({name:$(this).find("dd > h5 > a").text(),price:$(this).find("dd i").text()})})
# ```

# %% [markdown]
# # Problem 1's Solution
# # http://nbviewer.ipython.org/github/c3h3/nccu-crawler-courses-201411/blob/master/20141129LiveDemo.ipynb

# %%
import requests

# %%
res = requests.get("https://tw.stock.yahoo.com/d/s/major_2330.html")

# %%
from pyquery import PyQuery

# %%
S = PyQuery(res.text)

# %%
S("table").filter(lambda: len(PyQuery(PyQuery(this).find("tr")[0]).find("td")) == 8).find("tr")!
# Out:
# [<tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>, <tr>]

# %% [markdown]
# # Homework ..... complete it!

# %%
fdata = dict(map(lambda xx:tuple(xx.split("=")),"encodeURIComponent=1&step=1&firstin=1&TYPEK=sii&code=".split("&")))

# %%
fdata
# Out:
# {'TYPEK': 'sii',
#  'code': '',
#  'encodeURIComponent': '1',
#  'firstin': '1',
#  'step': '1'}

# %%
res = requests.post("http://mops.twse.com.tw/mops/web/ajax_t51sb01",data=fdata)

# %%
res.encoding = "utf8"

# %% [markdown]
# # HTML

# %%
PyQuery(res.text)("table")
# Out:
# [<table.noBorder>, <table>, <table.noBorder>]

# %%
pd.read_html(res.text)
# Out:
# [       0                 1                       2         3     4      5   \
#  0    公司代號              公司名稱                      住址  營利事業統一編號   董事長    總經理
#  1    1101        台灣水泥股份有限公司           台北市中山北路2段113號  11913502   辜成允    辜成允
#  2    1102        亞洲水泥股份有限公司  台北市大安區敦化南路2段207號30、31樓  03244509   徐旭東    李坤炎
#  3    1103        嘉新水泥股份有限公司            台北市中山北路2段96號  11892801   張剛綸    祁士鉅
#  4    1104        環球水泥股份有限公司        台北市南京東路二段125號10樓  07568009   侯博義    侯博義
#  5    1108        幸福水泥股份有限公司           台北市松江路237號15樓  40601248   陳兩傳    陳兩傳
#  6    1109        信大水泥股份有限公司             台北市寶慶路37號7樓  03279507   楊德雄    楊德雄
#  7    1110        東南水泥股份有限公司       高雄市前金區五福三路21號4樓之1  83078600   陳敏斷    吳長直
#  8    1201      味全食品工業股份有限公司              台北市松江路125號  11347802   李鳳翱    蘇守斌
#  9    1203          味王股份有限公司          台北市中山北路二段79號5樓  07067309  穎川建忠    陳恭平
#  10   1210      大成長城企業股份有限公司            台南市永康區蔦松二街三號  73008303   韓家宇    莊坤炎
# ...

# %% [markdown]
# #CSV

# %%
qstr = "firstin=true&step=10&filename=t51sb01_20150417_183959125.csv"

# %%
fdata = dict(map(lambda xx:tuple(xx.split("=")),qstr.split("&")))

# %%
fdata
# Out:
# {'filename': 't51sb01_20150417_183959125.csv', 'firstin': 'true', 'step': '10'}

# %%
cookie = {"newmops2":"TYPEK%3Dsii%7Ccode%3D%7C"}

# %%
requests.Request?

# %%
res = requests.post("http://mops.twse.com.tw/server-java/t105sb02",data=fdata,cookies=cookie)

# %%
res.encoding = "big5"

# %%
print res.text
# Out:
# "公司代號","公司名稱","住址","營利事業統一編號","董事長","總經理","發言人","發言人職稱","代理發言人","總機電話","成立日期","上市日期","普通股每股面額","實收資本額(元)","已發行普通股數或TDR原發行股數","私募普通股(股)","特別股(股)","編製財務報告類型","股票過戶機構","過戶電話","過戶地址","簽證會計師事務所","簽證會計師1","簽證會計師2","英文簡稱","英文通訊地址","傳真機號碼","電子郵件信箱","公司網址","公司網站內利害關係人專區網址"
# "1101","台灣水泥股份有限公司","台北市中山北路2段113號","	11913502","辜成允","辜成允","黃健強","資深副總經理","陳旭州","2531-7099","1950/12/29","1962/02/09",新台幣                 10.0000元,36921758690,3692175869,0,0,合併,"中國信託商業銀行代理部","66365566","台北市重慶南路一段83號5樓","勤業眾信聯合會計師事務所","翁雅玲","吳美慧","TCC","113 Chung Shan N.Road,Sec.2Taipei,Taiwan,R.O.C","2531-6529","finance@taiwancement.com","http://www.taiwancement.com","http://www.taiwancement.com/Csr_3_5.html"
# ...

# %% [markdown]
# #Gossiping

# %%
cookie = {"over18":"1"}

# %%
res = requests.get("https://www.ptt.cc/bbs/Gossiping/index.html",cookies=cookie)

# %%
res.history
# Out:
# []

# %%
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/pushstream.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-print.css" media="print" />
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.13/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
# ...

# %% [markdown]
# #內政部實價登錄

# %%
s = requests.Session()

# %%
r1 = s.get("http://lvr.land.moi.gov.tw/N11/homePage.action")

# %%
r1.cookies.get_dict()
# Out:
# {'JSESSIONID': '1B1BF1F845CB6FF92AF6919D1FBB7626.jvm1',
#  'slb_cookie': '16951488.20480.0000'}

# %%
r2 = s.get("http://lvr.land.moi.gov.tw/N11/ImageNumberN13?")

# %%
#r2.text

# %%
f = open("login_img.jpg", 'wb')
for chunk in r2.iter_content(chunk_size=512 * 1024): 
    if chunk: # filter out keep-alive new chunks
        f.write(chunk)
f.close()

# %% [markdown]
#  ![](login_img.jpg)

# %%
ca = 4001

# %%
TypeError
# Out:
# IOError

# %%
try:
    1+"1"
except IOError:
    print "123"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-10ce086b5784> in <module>()
#       1 try:
# ----> 2     1+"1"
#       3 except IOError:
#       4     print "123"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
res = requests.get("http://ecshweb.pchome.com.tw/search/v3.3/?q=sony")

# %%
res.encoding = "utf8"

# %%
res = requests.get("http://ecapi.pchome.com.tw/ecshop/prodapi/v2/prod?id=DCAN8M-A79783093,DCAN0C-A69908019,DCAN8I-A79595595,DCAV2W-A81106817,DSAR07-A62877570,DCAN8L-A79583156,DCAN8O-A9005LO0D,DGAX73-180460620&fields=Name,Pic,Price,Discount,isCarrier,isSpec,isSnapUp")

# %%
import json

# %%
import pandas as pd

# %%
pd.DataFrame(res.json()).T
# Out:
#                      Discount                             Name  \
# DCAN0C-A69908019-000        0                 羅技 無線充電式觸控板 T650
# DCAN8I-A79595595-000        0                          羅技木星軌跡球
# DCAN8L-A79583156-000        0                  羅技 T630 觸控滑鼠(黑)
# DCAN8M-A79783093-000        0                    羅技 G440 硬質滑鼠墊
# DCAN8O-A9005LO0D-000        0   微軟Arc Touch Bluetooth 藍芽滑鼠 (灰)
# DCAV2W-A81106817-000        0      Wacom Bamboo Pad (USB 有線系列)
# DGAX73-180460620-000        0  Apple Magic Trackpad(MC380FE/A)
# DSAR07-A62877570-000        0                     羅技 M600 觸控滑鼠
#
#                                                                     Pic  \
# DCAN0C-A69908019-000  {u'S': u'/pic/v1/data/item/201410/D/C/A/N/0/C/...
# DCAN8I-A79595595-000  {u'S': u'/pic/v1/data/item/201309/D/C/A/N/8/I/...
# DCAN8L-A79583156-000  {u'S': u'/pic/v1/data/item/201309/D/C/A/N/8/L/...
# DCAN8M-A79783093-000  {u'S': u'/pic/v1/data/item/201309/D/C/A/N/8/M/...
# ...

# %%
res = requests.get("http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=apple&page=1")

# %%
pd.DataFrame(res.json()["prods"])
# Out:
#                   Id author brand  cateId  \
# 0   DGAX73-A9005Y942               DGAX73
# 1   DGALU9-A9005RETE               DYAJ2N
# 2   DGALUM-A9005P5AN               DYAJ2J
# 3   DGALOL-A9005UIC7               DYAJ2O
# 4   DGALU9-A9005TJEP               DYAJ2N
# 5   DGALU9-A9005I8DG               DYAJ01
# 6   DGALUM-A9005TJES               DYAJ2J
# 7   DCACCW-A90059PL1               DCACCW
# 8   DGBWAV-A9005RJBR               DGBWAV
# 9   DGAX73-19005OJVI               DGAX73
# 10  DCAC62-A9005AHVO               DCAC62
# 11  DGBV4I-A9005YDVG               DGBV4I
# 12  DCACH3-A9005MXCJ               DCACH3
# 13  DGBOC3-A9005GX9X               DGBOC3
# 14  DCACCW-A90060KST               DCACCW
# 15  DGBWAV-A9005VGC2               DGBWAV
# 16  DGBP9Z-A9005UAQH               DYAF18
# 17  DGBOC3-A9005HCV5               DGBOC3
# 18  DGBOC7-A9005JUMX               DGBOC7
# 19  DGALUM-A9005T4TV               DYAJ2P
#
#                                              describe  isPick  \
# ...
